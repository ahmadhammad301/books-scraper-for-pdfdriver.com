# %%
from time import sleep
import os
from bs4 import BeautifulSoup
import pandas as pd
import requests
import wget
import concurrent
import tor_connection

# %%
search_url='https://www.pdfdrive.com/search?q={}&pagecount=&pubyear=&searchin=en&em='
base_url='https://www.pdfdrive.com'

# %%
def get_urls(url,all_pages=False):
    # input:
    # url: string --> in this format:'https://www.pdfdrive.com/search?q=data+science&pagecount=&pubyear=&searchin=&em='
    # all_pages: bool --> true: get all pages ,False--> get only first 2
    # output: list--> all urls in the search pages
    
    request= requests.get(url+"1")
    soup = BeautifulSoup(request.content,'lxml')
    
    if all_pages:   
        max_page=int(soup.select_one('div.Zebra_Pagination').find_all('a')[-2].text)
        print(max_pages)
    else:
        max_page=3
    
    print("getting links from page:  1")
    links=[]
    #scrape the first searct page and gather book links
    for ul in soup.find_all('ul')[1].find_all('li'):
        links.append(base_url+ul.find('a').attrs['href'])
        
    # scrape each other page    
    for page_num in range(2,max_page+1):
        
        request= requests.get(url+str(page_num))
        soup = BeautifulSoup(request.content,'lxml')
        
        print("getting links from page: ",page_num)
        for ul in soup.find_all('ul')[1].find_all('li'):
            links.append(base_url+ul.find('a').attrs['href'])
    print('number of book_urls',len(links))
    return links

# %%
def get_book(url,session):
    request= session.get(url)    
    book_soup=BeautifulSoup(request.content,'lxml') # make the soup from selenium driver

    # print("exception occured",e)
    title_ = book_soup.find('h1').text.strip()
    try:
        l=book_soup.find(class_='ebook-buttons').find('button').attrs['data-preview']
        download_url=base_url+'/download.pdf?'+l.split('session=')[0].split('?')[1]+'h='+l.split('session=')[1]+'&u=cache&ext=pdf'

    except:
        download_url='not found'
    
    book_details=dict(
            title = title_,
            book_page_url = url,
            download_url = download_url
        )
    print("book url in pdf:  ",download_url)
    
    return book_details

# %%
def download_book(book_idx):
    i=book_idx
    print(i)
    book_name = file['title'][i].replace(':',u'\uff1a')
    full_path = skill+"/"+book_name+".pdf"
    path=skill
    if file['download_url'][i] == 'not found ':
        print('book has no download url')
    else:
        full_path
        if not os.path.exists(path):
            os.makedirs(path)

        if  os.path.exists(full_path):
            print('book exists')
        else:
            wget.download(file['download_url'][i], "{}".format(full_path))
        print(full_path)

# %%
if __name__=="__main__":
    
    skill = input("Enter the skill: ")
    skill = skill.replace(" ","%20")
    url = search_url.format(skill)
    all_book_urls=[]
    all_book_urls = get_urls(url)
    
    books=[]
    count=0

    tor_connection.renew_connection()
    session = tor_connection.get_tor_session()
    for idx,url in enumerate(all_book_urls):
       
        print("book num {} of {}, url:  {}".format(idx+1,len(all_book_urls),url))
        
        # change the scraper ip every 100 request
        if idx % 100 == 0:
            tor_connection.renew_connection()
            session = tor_connection.get_tor_session()

        books.append(get_book(url,session))
    
    #saving in an excel file 
    file=pd.DataFrame(books)
    file.drop_duplicates(inplace=True)
    
    skill=skill.replace("%20",' ')+' books'
    file.to_excel('{}.xlsx'.format(skill),index=False,encoding='utf-8-sig')
    print('excel file saved')
    
    # downloading books
    #resource https://docs.python.org/3/library/concurrent.futures.html
    book_index =[i for i in range(len(file))]
    with concurrent.futures.ThreadPoolExecutor() as executor:
        results =concurrent.futures.wait([executor.submit(download_book, index) for index in book_index])
    print('books downloaded')
# Out:
# getting links from page:  1
# getting links from page:  2
# getting links from page:  3
# number of book_urls 60
# book num 1 of 60, url:  https://www.pdfdrive.com/data-science-big-data-analytics-e33407829.html
# book url in pdf:   https://www.pdfdrive.com/download.pdf?id=33407829&h=4d3b765e83adaee467ac7dfcd060b65f&u=cache&ext=pdf
# book url in pdf:   https://www.pdfdrive.com/download.pdf?id=189545567&h=c2722b8521cbe49c7124f60b29e4bf1a&u=cache&ext=pdf
# book num 29 of 60, url:  https://www.pdfdrive.com/ai-in-marketing-sales-and-service-how-marketers-without-a-data-science-degree-can-use-ai-big-data-and-bots-e176382879.html
# book url in pdf:   https://www.pdfdrive.com/download.pdf?id=176382879&h=c7f4d52d2c430c4f83d1e976bf06ad34&u=cache&ext=pdf
# book num 30 of 60, url:  https://www.pdfdrive.com/data-analytics-practical-guide-to-leveraging-the-power-of-algorithms-data-science-data-mining-statistics-big-data-and-predictive-analysis-to-improve-business-work-and-life-e199774884.html
# book url in pdf:   https://www.pdfdrive.com/download.pdf?id=199774884&h=7ad97203952951ec7f1a40021b04f13f&u=cache&ext=pdf
# book num 31 of 60, url:  https://www.pdfdrive.com/big-data-data-mining-and-machine-learning-e33454197.html
# book url in pdf:   https://www.pdfdrive.com/download.pdf?id=33454197&h=fadf2b2ade0d6efbed9db7922f360969&u=cache&ext=pdf
# book num 32 of 60, url:  https://www.pdfdrive.com/statistical-and-machine-learning-data-mining-third-edition-techniques-for-better-predictive-modeling-and-analysis-of-big-data-third-edition-e176382228.html
# book url in pdf:   https://www.pdfdrive.com/download.pdf?id=176382228&h=5ab9c948ef8341e23722b850ffd258ae&u=cache&ext=pdf
# book num 33 of 60, url:  https://www.pdfdrive.com/data-science-and-big-data-analytics-e58447171.html
# book url in pdf:   https://www.pdfdrive.com/download.pdf?id=58447171&h=adad844fec11895591b6cd34ffb802a7&u=cache&ext=pdf
# book num 34 of 60, url:  https://www.pdfdrive.com/data-structures-and-algorithms-made-easy-data-structures-and-algorithmic-puzzles-e158226594.html
# book url in pdf:   https://www.pdfdrive.com/download.pdf?id=158226594&h=d9a09e7e092770b490569037e38267ec&u=cache&ext=pdf
# book num 35 of 60, url:  https://www.pdfdrive.com/storytelling-with-data-a-data-visualization-guide-for-business-professionals-e166953228.html
# book url in pdf:   https://www.pdfdrive.com/download.pdf?id=166953228&h=501cea7f598b99bbe8f412abe07100e0&u=cache&ext=pdf
# book num 36 of 60, url:  https://www.pdfdrive.com/the-enterprise-big-data-lake-delivering-the-promise-of-big-data-and-data-science-e187707745.html
# book url in pdf:   https://www.pdfdrive.com/download.pdf?id=187707745&h=ef16727905cb47eb1998479fd2be22b7&u=cache&ext=pdf
# book num 37 of 60, url:  https://www.pdfdrive.com/big-data-demystified-how-to-use-big-data-data-science-and-ai-to-make-better-business-decisions-e187913832.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-a7b42ea7bfea> in <module>
#      21             session = tor_connection.get_tor_session()
#      22
# ---> 23         books.append(get_book(url,session))
#      24
#      25     #saving in an excel file
#
# <ipython-input-4-00da97e6080d> in get_book(url, session)
#       1 def get_book(url,session):
# ----> 2     request= session.get(url)
#       3     book_soup=BeautifulSoup(request.content,'lxml') # make the soup from selenium driver
#       4
#       5     # print("exception occured",e)
#
# c:\Users\hamad\anaconda3\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     553
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#     557     def options(self, url, **kwargs):
#
# c:\Users\hamad\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# c:\Users\hamad\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# c:\Users\hamad\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# c:\Users\hamad\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# c:\Users\hamad\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\Users\hamad\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\Users\hamad\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# c:\Users\hamad\anaconda3\lib\http\client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# c:\Users\hamad\anaconda3\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# c:\Users\hamad\anaconda3\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# c:\Users\hamad\anaconda3\lib\socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# c:\Users\hamad\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# c:\Users\hamad\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
